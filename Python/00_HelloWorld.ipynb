# %%
# Este simbolo se utiliza para comentar el codigo.
print("Hola grupo 430 de la carrera tecnica de PEOGRAMACÓN")
#Como consultar un tipo de dato
print(type("Soy un dato Str")) #Tipo 'str'
print(type(5)) #Tipo 'int'
print(type(1.5)) #Tipo 'float'
print(type(3+1j)) #Tipo 'complex
print(type(True)) #Tipo 'bool'
print(type(print("Mi cadena de texto"))) #Tipo 'None Type'
# Out:
# Hola grupo 430 de la carrera tecnica de PEOGRAMACÓN
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# Mi cadena de texto
# <class 'NoneType'>
